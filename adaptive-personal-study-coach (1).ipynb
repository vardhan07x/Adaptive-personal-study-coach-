# %% [markdown]
# **🧠 Adaptive Personal Study Coach — Multi-Agent System **
#
# A notebook that listens, learns, and reshapes your study patterns. A study planner that behaves less like a rigid timetable and more like a gentle compass — adjusting direction as your energy, mood, and habits ebb and glow. This system blends Gemini reasoning, rule-based agents, and lightweight storage into a coordinated trio:
#
# Memory Agent — remembers what you did, wanted to do, and forgot to do
# Planner Agent — takes a task and unmasks its smaller bones (subtasks)
# Recommender Agent — reads your energy/mood levels and shapes a schedule
# Controller — orchestrates everything, ensuring responses don’t trip over each other
#
# We’ll build all of this in calm, deliberate stages — each wrapped in its own section, like chapters in a small technical fable.

# %% [markdown]
# DATA FLOW DIAGRAM (Conceptual)
# flowchart TD
#
#     U[User: Task + Mood + Energy] --> C[Controller]
#
#     C --> P[Planner Agent<br>Gemini decomposition]
#     C --> R[Recommender Agent<br>Mood-Energy reasoning]
#
#     P --> C
#     R --> C
#
#     C --> M[Memory Agent<br>TinyDB storage]
#
#     C --> O[Final Optimized Study Plan]
#
#     M --> H[History / Logs]
# This mermaid diagram gently maps out the pipeline of thought from user → agents → memory.

# %%
# !pip install --quiet tinydb python-dateutil

# %% [markdown]
# 🔧 SECTION 1 — Imports & Utilities

# %%
from tinydb import TinyDB, Query
from datetime import datetime
from dateutil import parser
import uuid
import os
import requests
import json

# %% [markdown]
# A few helper utilities (timestamps, safe prints, etc.) will appear later as needed — no clutter yet.

# %% [markdown]
# 🔐 SECTION 2 — Gemini API Key Authentication
#
# Kaggle likes secrets tucked away safely.
# This cell gently retrieves the API key and sets it into the environment.

# %%
# ============================================================
# 🔐 Gemini API Key Authentication (Kaggle Secrets)
# ============================================================

from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please add 'GOOGLE_API_KEY' to Kaggle Secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %% [markdown]
# 🌩 SECTION 3 — Gemini API Wrapper
#
# A small, quiet function that handles all communication with the Gemini model.

# %%
API_KEY = os.environ.get("GOOGLE_API_KEY")
MODEL = "gemini-2.5-flash"
URL = f"https://generativelanguage.googleapis.com/v1beta/models/{MODEL}:generateContent?key={API_KEY}"

def ask_gemini(prompt: str) -> str:
    """
    Sends a prompt to Gemini and returns the generated text.
    """
    body = {"contents": [{"parts": [{"text": prompt}]}]}
    
    response = requests.post(URL, json=body)
    data = response.json()
    
    try:
        return data["candidates"][0]["content"]["parts"][0]["text"]
    except:
        return f"[Gemini Error] {data}"

# %% [markdown]
# 🎒 SECTION 4 — TinyDB Memory Layer
#
# A memory not as fragile as RAM, not as heavy as SQL — just right for our quiet little agent.

# %%
db = TinyDB("memory.json")
Memory = Query()

def save_memory(entry):
    entry["id"] = str(uuid.uuid4())
    entry["timestamp"] = datetime.now().isoformat()
    db.insert(entry)

def get_all_memory():
    return db.all()

# %% [markdown]
# 🗂 SECTION 5 — Memory Agent
#
# A soft archivist that stores:
#
# What tasks you planned
#
# What you finished
#
# What overwhelmed you
#
# What mood/energy you were in
#
# Think of it as a journal written in tiny, structured whispers.

# %%
db = TinyDB("memory.json")
Memory = Query()

def save_memory(entry):
    entry["id"] = str(uuid.uuid4())
    entry["timestamp"] = datetime.now().isoformat()
    db.insert(entry)

def get_all_memory():
    return db.all()

# %%
class MemoryAgent:
    def __init__(self, db):
        self.db = db

    def record_task(self, task, status, mood=None, energy=None):
        entry = {
            "type": "task_record",
            "task": task,
            "status": status,
            "mood": mood,
            "energy": energy,
        }
        save_memory(entry)

    def record_feedback(self, feedback):
        entry = {"type": "feedback", "feedback": feedback}
        save_memory(entry)

    def fetch_history(self):
        return get_all_memory()

# %%
memory_agent = MemoryAgent(db)
memory_agent.record_task("Study Operating Systems", "completed", mood="calm", energy="medium")

# %% [markdown]
# This deposits a small story into your “memory.json” vault.

# %% [markdown]
# 🧩 SECTION 6 — Planner Agent
#
# The planner is a sculptor — it takes a rough task like:
#
# “Prepare for Machine Learning exam”
#
# … and chips it into finer, workable pieces:
#
# Collect syllabus
#
# Gather notes
#
# Solve PYQs
#
# Run revision loops
#
# It uses Gemini for decomposition so that tasks become smooth and chewable.

# %%
class PlannerAgent:
    def __init__(self):
        pass

    def decompose(self, task: str):
        prompt = (
            "Break the following study task into 5–8 actionable subtasks. "
            "Respond only with a numbered list.\n\n"
            f"Task: {task}"
        )
        output = ask_gemini(prompt)
        return output

# %%
planner = PlannerAgent()
subtasks = planner.decompose("Revise Data Structures")
print(subtasks)
# Out:
# 1.  Review course syllabus and previous notes to identify all topics covered.
# 2.  Create a quick reference guide (flashcards or summary sheet) for each data structure, including definitions, properties, and common operations.
# 3.  Analyze and memorize the time and space complexity (Big O notation) for key operations on each data structure.
# 4.  Review pseudo-code or actual code implementations for core operations and algorithms (e.g., traversals, insertions, deletions).
# 5.  Solve a variety of practice problems that require applying different data structures to real-world scenarios.
# 6.  Identify specific data structures or algorithms you struggled with during practice.
# 7.  Deep-dive into those identified weak areas through additional examples, tutorials, or focused practice.
# 8.  Take a self-assessment or work through a mock exam to test overall understanding and recall.

# %% [markdown]
# You’ll receive a neatly chiseled list of steps.

# %% [markdown]
# ⚖️ SECTION 7 — Recommender Agent
#
# This one listens to your mood and energy, like a quiet physiologist.
#
# Low energy? → short, soft tasks
#
# High motivation? → deep work
#
# Stressed? → review-oriented schedule
#
# Bored? → variety injection

# %%
class RecommenderAgent:
    def __init__(self):
        pass

    def recommend(self, subtasks: str, mood: str, energy: str):
        prompt = (
            f"You are an adaptive study recommender.\n"
            f"Given the user's mood: {mood} and energy: {energy},\n"
            f"reorder or enhance the following subtasks to create an optimal study sequence.\n\n"
            f"Subtasks:\n{subtasks}"
        )
        return ask_gemini(prompt)

# %%
recommender = RecommenderAgent()
rec = recommender.recommend(
    subtasks,
    mood="tired",
    energy="low"
)
print(rec)
# Out:
# Given your mood (tired) and energy (low), the key is to prioritize tasks that are less mentally demanding, offer quick wins, and can be done in short, focused bursts. Avoid tasks that require sustained deep analytical thinking or can lead to frustration.
#
# Here's an optimized study sequence, enhanced for your current state:
#
# ---
#
# **Optimal Study Sequence for Tired & Low Energy:**
#
# **Phase 1: Gentle Warm-up & Overview (Minimal Cognitive Load)**
#
# 1.  **Review course syllabus and previous notes to identify all topics covered.**
#     *   **Enhancement:** Don't re-read everything in detail. Instead, **skim through topic headings** to refresh your memory of the scope. Focus on creating a mental checklist of what you *need* to cover, not on mastering it now. This is about orientation and activating prior knowledge.
#     *   *(Goal: 5-10 minutes)*
#
# 2.  **Briefly review existing quick reference guides or flashcards.**
#     *   **Enhancement:** If you already have flashcards or summary sheets, simply **flip through them quickly**. Focus on quick recall of definitions and key properties. If you don't have them, consider spending **5 minutes jotting down 1-2 key points** for a couple of major data structures – just enough to engage your brain without making it a full creation task.
#     *   *(Goal: 10-15 minutes)*
#
#     *   **Short Break (5 minutes):** Stand up, stretch, grab water.
#
# **Phase 2: Focused Recall & Conceptual Reinforcement (Low-Medium Cognitive Load)**
#
# 3.  **Review the time and space complexity (Big O notation) for *key operations* on each data structure.**
#     *   **Enhancement:** Instead of deep analysis, **focus on recognizing and understanding the intuition** behind the most common complexities (e.g., O(1), O(log n), O(n), O(n log n), O(n²)). Use visual aids if available, or try to recall a simple reason *why* a particular operation is, for example, O(n). Don't try to derive them from scratch.
#     *   *(Goal: 15-20 minutes)*
#
# 4.  **Review pseudo-code or actual code implementations for core operations and algorithms.**
#     *   **Enhancement:** **Choose one or two simple examples** (e.g., array insertion, linked list traversal). **Read through the code or pseudo-code slowly, focusing on understanding the *logic and flow*** rather than memorizing syntax. Trace a very small input mentally if you can, but don't try to debug or write code yourself. Visualizing the steps is key here.
#     *   *(Goal: 20-25 minutes)*
#
#     *   **Longer Break (10-15 minutes):** Step away from your study area. Listen to some music, make a cup of tea, or do something completely unrelated to clear your head.
#
# **Phase 3: Targeted Reinforcement & Light Practice (Medium-High Cognitive Load - *Optional/Conditional*)**
#
# 5.  **Identify specific data structures or algorithms you *know* you've struggled with previously.**
#     *   **Enhancement:** Don't overthink this. Based on your quick reviews, or past experience, **list 1-2 topics where you feel least confident.** The goal is just identification, not immediate resolution.
#     *   *(Goal: 5 minutes)*
#
# 6.  **Deep-dive into *one* of those identified weak areas through additional *simple* examples or concise tutorials.**
#     *   **Enhancement:** Choose just *one* of the identified weak areas. **Find a very short (5-10 minute) video explanation or a simple tutorial** that clarifies the core concept. Focus on understanding *why* it works the way it does, rather than exhaustive coverage. The goal is a minor "aha!" moment, not complete mastery.
#     *   *(Goal: 15-20 minutes)*
#
# 7.  **Attempt one or two *very easy* practice problems.**
#     *   **Enhancement:** **Choose problems that are explicitly labeled as "easy" or "introductory."** The moment you feel stuck or frustrated for more than 2-3 minutes, **immediately look at the solution and walk through it.** The aim is exposure to application, not necessarily independent problem-solving right now. Understand *how* the solution applies the concepts you just reviewed.
#     *   *(Goal: 20-30 minutes)*
#
# **Phase 4: Light Self-Assessment & Wrap-up (Low-Medium Cognitive Load - *Optional*)**
#
# 8.  **Take a *very short* self-assessment.**
#     *   **Enhancement:** Don't do a full mock exam. Instead, **answer 2-3 quick multiple-choice questions** on a topic you just reviewed, or **verbally explain a definition or concept** to yourself. This is a quick check to see what stuck, and it should feel low-pressure.
#     *   *(Goal: 5-10 minutes)*
#
# ---
#
# **Key Principles for Studying When Tired:**
#
# *   **Breaks are Essential:** Integrate frequent, short breaks to prevent burnout.
# *   **Prioritize Review Over New Learning:** Leverage existing knowledge as much as possible.
# *   **Focus on Understanding, Not Memorization:** Aim for conceptual clarity, which is less draining.
# *   **Keep Tasks Short:** Break down larger tasks into smaller, manageable chunks.
# *   **Listen to Your Body:** If a task feels too overwhelming, switch to something lighter or consider ending the session and resting. Even a short, focused session is better than none.
# *   **Celebrate Small Wins:** Acknowledge that you're making progress even with low energy.

# %% [markdown]
# 🎛 SECTION 8 — Controller Agent (the conductor)
#
# This ties everything together.
# A maestro waving calmly while the Memory, Planner, and Recommender play their notes.

# %%
class Controller:
    def __init__(self, memory_agent, planner_agent, recommender_agent):
        self.memory = memory_agent
        self.planner = planner_agent
        self.recommender = recommender_agent

    def process_task(self, task, mood, energy):
        subtasks = self.planner.decompose(task)
        plan = self.recommender.recommend(subtasks, mood, energy)

        self.memory.record_task(task, "planned", mood, energy)

        return {
            "subtasks": subtasks,
            "final_plan": plan,
            "history": self.memory.fetch_history()
        }

# %%
controller = Controller(memory_agent, planner, recommender)

result = controller.process_task(
    task="Prepare for DBMS exam",
    mood="neutral",
    energy="medium"
)

result
# Out:
# {'subtasks': '1.  **Consolidate All Study Materials:** Gather lecture notes, textbook chapters, assignments, and past quizzes/exams.\n2.  **Outline Key DBMS Topics:** Create a comprehensive list of all major concepts to be covered (e.g., ER models, Relational Algebra, SQL, Normalization, Transactions, Indexing, Concurrency, Recovery).\n3.  **Review Core Concepts and Theory:** Systematically go through each topic, focusing on understanding definitions, principles, and algorithms (e.g., ACID properties, B-trees, join types).\n4.  **Practice SQL Querying and DDL/DML:** Solve a variety of SQL problems, including SELECT, INSERT, UPDATE, DELETE, CREATE TABLE, JOINs, subqueries, and aggregate functions.\n5.  **Work Through Practical Problems:** Practice ER diagramming, normalization (1NF to BCNF/4NF), transaction schedule analysis, and index cost estimation.\n6.  **Complete Practice Exams/Questions:** Work through past exam papers, textbook practice problems, or online quizzes under timed conditions if possible.\n7.  **Identify Weak Areas and Revisit:** Based on practice, pinpoint topics you struggle with and dedicate extra study time to them.\n8.  **Create a Summary/Cheat Sheet and Final Review:** Condense key formulas, concepts, and SQL syntax onto a concise sheet for active recall and a final overview.',
#  'final_plan': 'Given your **neutral mood** and **medium energy**, the goal is to create a structured and engaging study sequence that builds momentum without overwhelming you. We\'ll start with organizational tasks, progressively move into core learning and application, and incorporate natural breaks through task switching.\n\nHere\'s an optimal study sequence with enhancements:\n\n---\n\n### Optimal DBMS Study Sequence for Neutral Mood & Medium Energy\n\n1.  **Consolidate All Study Materials**\n    *   **Enhancement:** Make this a quick, low-stress setup. Simply gather everything into one physical or digital folder. No deep reading yet, just organization. This helps you feel prepared without expending much energy.\n\n2.  **Outline Key DBMS Topics & Initial Confidence Check**\n    *   **Enhancement:** As you list the major concepts (ER models, SQL, Normalization, etc.), briefly rate your current confidence for each (e.g., Green for good, Yellow for needs review, Red for unfamiliar). This creates a personalized roadmap and helps you see the scope without getting bogged down, which is good for a neutral mood.\n\n3.  **Review Core Concepts and Theory (Segmented & Focused)**\n    *   **Enhancement:** Based on your outline from step 2, pick 2-3 "Yellow" or "Green" topics to start with – something you feel moderately comfortable with or can grasp relatively quickly. Focus on understanding definitions and principles.\n    *   **Tip:** After each major concept (e.g., "Relational Algebra"), take a very short active recall break: try to explain it aloud or jot down the main points from memory. This prevents passive reading and boosts engagement.\n\n4.  **Practice SQL Querying and DDL/DML (Hands-on Application)**\n    *   **Enhancement:** This is a great way to transition from theory to practice and maintain engagement. Start with basic SELECT statements, then move to INSERT/UPDATE/DELETE, and eventually JOINs or subqueries. If you just reviewed Relational Algebra in step 3, try to map some of those operations to SQL queries.\n    *   **Tip:** Use an online SQL playground or your local database to run these queries and see immediate results. This interactive element can combat a neutral mood.\n\n5.  **Work Through Practical Problems (Deeper Application)**\n    *   **Enhancement:** Now, tackle the more analytical problems. Focus on areas like ER diagramming, normalization steps (1NF to BCNF/4NF), or transaction analysis.\n    *   **Tip:** Alternate problem types to keep your mind fresh (e.g., do an ER diagram problem, then a normalization problem, then a cost estimation). This prevents mental fatigue from focusing on one type for too long, which is beneficial for medium energy.\n\n6.  **Complete Targeted Practice Questions/Mini-Quizzes**\n    *   **Enhancement:** Instead of a full-blown practice exam right away, which can be draining for medium energy, choose specific sets of questions related to the topics you\'ve covered in steps 3-5. Treat these like short, focused assessments.\n    *   **Tip:** If you complete a set of questions, take a 5-10 minute break to stretch or grab a drink before moving on. This helps reset your energy levels.\n\n7.  **Identify Weak Areas and Revisit (Targeted Review)**\n    *   **Enhancement:** Based on the practice questions, pinpoint exactly where you struggled. Go back to your outline and turn those "Yellow" topics into "Red" if needed.\n    *   **Tip:** Prioritize revisiting the most impactful or frequently occurring weak areas. Don\'t try to re-learn everything; focus on clarifying specific misconceptions or practicing the *types* of problems you found challenging.\n\n8.  **Create a Summary/Cheat Sheet and Final Review**\n    *   **Enhancement:** This is a powerful active recall exercise. Condense key formulas, concepts, and SQL syntax onto a concise sheet. Don\'t just copy; *synthesize* the information.\n    *   **Tip:** Imagine this as the ultimate "quick reference" you\'d want right before an exam. R ...
#  'history': [{'type': 'task_record',
#    'task': 'Study Operating Systems',
#    'status': 'completed',
#    'mood': 'calm',
#    'energy': 'medium',
#    'id': '2e853ecb-3a63-4dcb-9ad1-9c304fbc7c05',
#    'timestamp': '2025-11-30T12:49:31.758573'},
#   {'type': 'task_record',
#    'task': 'Prepare for DBMS exam',
#    'status': 'planned',
#    'mood': 'neutral',
#    'energy': 'medium',
#    'id': '6094a9ce-f86a-4403-b013-a825618dac08',
#    'timestamp': '2025-11-30T12:50:15.132126'}]}

# %% [markdown]
# 🧪 SECTION 9 — First System Test (Dry Run)
#
# A gentle warm-up run to make sure all the gears mesh.

# %%
# Quick system test
controller = Controller(memory_agent, planner, recommender)

test_output = controller.process_task(
    task="Revise Computer Networks",
    mood="relaxed",
    energy="high"
)

test_output
# Out:
# {'subtasks': '1.  Review the course syllabus and learning objectives to identify all covered topics.\n2.  Skim through all lecture notes and textbook chapters to get an overview and identify familiar versus challenging areas.\n3.  Deeply study specific challenging topics, consulting textbooks, online resources, and supplementary materials as needed.\n4.  Work through practice problems, past exam questions, or lab exercises related to core concepts.\n5.  Create summary notes, flashcards, or mind maps for key protocols, architectures (e.g., OSI, TCP/IP), and algorithms.\n6.  Explain complex concepts (e.g., routing protocols, congestion control) aloud or to a study partner to solidify understanding.\n7.  Review network topologies and protocol interactions using diagrams and example scenarios.\n8.  Conduct a final self-assessment or timed practice session to gauge readiness.',
#  'final_plan': "This is an excellent state for tackling substantial learning! Your high energy allows for deep engagement and sustained focus, while a relaxed mood enables thoroughness and a less rushed approach to complex topics.\n\nHere's an optimal study sequence, leveraging your mood and energy, with enhancements for each subtask:\n\n---\n\n### Optimal Study Sequence for a Relaxed & High-Energy State:\n\n**Phase 1: Comprehensive Orientation & Gap Identification (Leverage high energy for initial sweep & focus)**\n\n1.  **Review the course syllabus and learning objectives to identify all covered topics.**\n    *   **Enhancement:** Use your relaxed state to meticulously read through the syllabus. Highlight key themes, understand assessment criteria, and note the weight given to different topics. This sets a clear scope for your high-energy session and helps you prioritize.\n2.  **Skim through all lecture notes and textbook chapters to get an overview and identify familiar versus challenging areas.**\n    *   **Enhancement:** With high energy, quickly scan headings, bolded terms, and summaries. Don't get bogged down. Actively mark or make a quick list of sections that appear particularly complex, unfamiliar, or dense. This rapid reconnaissance helps you pinpoint where your high energy will be most effectively spent.\n\n**Phase 2: Deep Dive & Active Conceptual Understanding (Utilize peak energy for demanding cognitive work)**\n\n3.  **Deeply study specific challenging topics, consulting textbooks, online resources, and supplementary materials as needed.**\n    *   **Enhancement:** This is where your high energy is crucial. Dive into those challenging areas identified in step 2. Don't just read; actively engage. Take detailed notes, draw your own diagrams, and pause to mentally summarize each section. Use your relaxed mood to allow ample time for full comprehension without feeling rushed.\n4.  **Review network topologies and protocol interactions using diagrams and example scenarios.**\n    *   **Enhancement:** As you're deep-diving (or immediately after covering a specific topic), make this a highly interactive process. Don't just look at diagrams; *recreate* them. Trace the path of data packets through different topologies (e.g., bus, star, mesh) and verbally explain the steps of protocol interactions (e.g., TCP handshake, routing table updates) to yourself or an imaginary partner. This visual and active engagement is perfect for your high-energy state.\n\n**Phase 3: Application & Active Recall (Solidify understanding through practice and explanation)**\n\n5.  **Work through practice problems, past exam questions, or lab exercises related to core concepts.**\n    *   **Enhancement:** Immediately apply what you've just deeply studied. Your high energy will allow you to persist through challenging problems. Focus on understanding *why* a solution works, not just memorizing it. If you get stuck, identify the precise concept you're struggling with and refer back to your notes or resources from step 3.\n6.  **Explain complex concepts (e.g., routing protocols, congestion control) aloud or to a study partner to solidify understanding.**\n    *   **Enhancement:** This is a powerful active recall technique. Before moving to summary notes, test your understanding by explaining a concept from scratch. Pretend you're teaching it to someone who knows nothing about it. Your relaxed mood will help you articulate clearly, and your high energy will ensure you can maintain focus through the entire explanation, exposing any gaps in your knowledge. If no partner is available, record yourself or explain it to a rubber duck!\n\n**Phase 4: Synthesis & Creation of Study Aids (Consolidate knowledge for long-term retention)**\n\n7.  **Create summary notes, flashcards, or mind maps for key protocols, architectures (e.g., OSI, TCP/IP), and algorithms.**\n    *   **Enhancement:** Now that you've deeply understood, applied, and explained, synthesize your k ...
#  'history': [{'type': 'task_record',
#    'task': 'Study Operating Systems',
#    'status': 'completed',
#    'mood': 'calm',
#    'energy': 'medium',
#    'id': '2e853ecb-3a63-4dcb-9ad1-9c304fbc7c05',
#    'timestamp': '2025-11-30T12:49:31.758573'},
#   {'type': 'task_record',
#    'task': 'Prepare for DBMS exam',
#    'status': 'planned',
#    'mood': 'neutral',
#    'energy': 'medium',
#    'id': '6094a9ce-f86a-4403-b013-a825618dac08',
#    'timestamp': '2025-11-30T12:50:15.132126'},
#   {'type': 'task_record',
#    'task': 'Revise Computer Networks',
#    'status': 'planned',
#    'mood': 'relaxed',
#    'energy': 'high',
#    'id': '766537a1-a34d-49df-b978-dbf08967c145',
#    'timestamp': '2025-11-30T12:50:34.131978'}]}

# %% [markdown]
# 📚 SECTION 10 — Memory Explorer Cell
#
# A tiny window into the notebook’s inner diary.
# Useful for debugging, evaluation, or curiosity.

# %%
# Inspect what the system remembers so far
memory_agent.fetch_history()
# Out:
# [{'type': 'task_record',
#   'task': 'Study Operating Systems',
#   'status': 'completed',
#   'mood': 'calm',
#   'energy': 'medium',
#   'id': '2e853ecb-3a63-4dcb-9ad1-9c304fbc7c05',
#   'timestamp': '2025-11-30T12:49:31.758573'},
#  {'type': 'task_record',
#   'task': 'Prepare for DBMS exam',
#   'status': 'planned',
#   'mood': 'neutral',
#   'energy': 'medium',
#   'id': '6094a9ce-f86a-4403-b013-a825618dac08',
#   'timestamp': '2025-11-30T12:50:15.132126'},
#  {'type': 'task_record',
#   'task': 'Revise Computer Networks',
#   'status': 'planned',
#   'mood': 'relaxed',
#   'energy': 'high',
#   'id': '766537a1-a34d-49df-b978-dbf08967c145',
#   'timestamp': '2025-11-30T12:50:34.131978'}]

# %% [markdown]
# 🎛 SECTION 11 — Interactive Study Prompt (Mini UI)
#
# A soft, terminal-style interface inside the notebook.
# Lightweight, no libraries required.

# %% [markdown]
# This turns your notebook into a calm conversational partner.

# %% [markdown]
# 🪞 SECTION 12 — Feedback Loop
#
# Improves the system over time by storing your reflections.

# %%
import gradio as gr

def interact_ui(task, mood, energy):
    result = controller.process_task(task, mood, energy)
    
    return (
        result["subtasks"],
        result["final_plan"],
        "Memory updated successfully ✔️"
    )

ui = gr.Interface(
    fn=interact_ui,
    inputs=[
        gr.Textbox(label="Enter your study task"),
        gr.Dropdown(["calm", "stressed", "neutral"], label="Your current mood"),
        gr.Dropdown(["low", "medium", "high"], label="Your energy level"),
    ],
    outputs=[
        gr.Textbox(label="🧩 Subtasks"),
        gr.Textbox(label="🎯 Personalized Plan"),
        gr.Textbox(label="🗂 Memory Status")
    ],
    title="📌 Adaptive Study Planner",
    description="Gemini-powered multi-agent study planner"
)

ui.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://590501965511084b03.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://590501965511084b03.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# 🧹 SECTION 13 — Memory Cleaning Utilities (
#
# Admins sometimes want to wipe memory before submitting or testing.

# %%
def clear_memory(confirm=False):
    if confirm:
        db.truncate()
        print("🧼 Memory wiped clean.")
    else:
        print("Set confirm=True to wipe memory.")

# Example: clear_memory(confirm=True)

# %% [markdown]
# 🌙 14 — COMPLETION BANNER

# %%
print("✨ Study Coach Notebook fully initialized.")
# Out:
# ✨ Study Coach Notebook fully initialized.
